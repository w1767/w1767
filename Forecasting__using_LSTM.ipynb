# %% [markdown]
# <a href="https://colab.research.google.com/github/w1767/w1767/blob/main/Forecasting__using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip
# 13574144/13568290 [==============================] - 0s 0us/step
# 13582336/13568290 [==============================] - 0s 0us/step

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# 0       01.01.2009 00:10:00    996.52  ...           1.75     152.3
# 1       01.01.2009 00:20:00    996.57  ...           1.50     136.1
# 2       01.01.2009 00:30:00    996.53  ...           0.63     171.6
# 3       01.01.2009 00:40:00    996.51  ...           0.50     198.0
# 4       01.01.2009 00:50:00    996.51  ...           0.63     214.3
# ...                     ...       ...  ...            ...       ...
# 420546  31.12.2016 23:20:00   1000.07  ...           1.52     240.0
# 420547  31.12.2016 23:30:00    999.93  ...           1.92     234.3
# 420548  31.12.2016 23:40:00    999.82  ...           2.00     215.2
# 420549  31.12.2016 23:50:00    999.81  ...           2.16     225.8
# 420550  01.01.2017 00:00:00    999.82  ...           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# 5       01.01.2009 01:00:00    996.50  ...           0.63     192.7
# 11      01.01.2009 02:00:00    996.62  ...           0.63     190.3
# 17      01.01.2009 03:00:00    996.84  ...           0.63     167.2
# 23      01.01.2009 04:00:00    996.99  ...           0.38     240.0
# 29      01.01.2009 05:00:00    997.46  ...           0.88     157.0
# ...                     ...       ...  ...            ...       ...
# 420521  31.12.2016 19:10:00   1002.18  ...           1.36     190.6
# 420527  31.12.2016 20:10:00   1001.40  ...           1.92     225.4
# 420533  31.12.2016 21:10:00   1001.19  ...           1.56     158.7
# 420539  31.12.2016 22:10:00   1000.65  ...           0.68     216.7
# 420545  31.12.2016 23:10:00   1000.11  ...           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.head()
# Out:
#               Date Time  p (mbar)  T (degC)  ...  wv (m/s)  max. wv (m/s)  wd (deg)
# 5   01.01.2009 01:00:00    996.50     -8.05  ...      0.21           0.63     192.7
# 11  01.01.2009 02:00:00    996.62     -8.88  ...      0.25           0.63     190.3
# 17  01.01.2009 03:00:00    996.84     -8.81  ...      0.18           0.63     167.2
# 23  01.01.2009 04:00:00    996.99     -9.05  ...      0.10           0.38     240.0
# 29  01.01.2009 05:00:00    997.46     -9.63  ...      0.40           0.88     157.0
#
# [5 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  ...  max. wv (m/s)  wd (deg)
# Date Time                                           ...
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50  ...           0.63     192.7
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62  ...           0.63     190.3
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84  ...           0.63     167.2
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99  ...           0.38     240.0
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46  ...           0.88     157.0
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71  ...           0.50     146.0
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33  ...           2.88     348.8
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17  ...           1.25     213.9
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69  ...           0.63     202.2
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27  ...           3.00     292.6
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87  ...           3.38     269.6
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30  ...           2.63     184.4
# 2009-01-01 13:00:00  01.01.2009 13:00:00   1000.03  ...           1.25     187.3
# 2009-01-01 14:00:00  01.01.2009 14:00:00    999.81  ...           2.00     144.0
# 2009-01-01 15:00:00  01.01.2009 15:00:00    999.88  ...           1.88     134.9
# 2009-01-01 16:00:00  01.01.2009 16:00:00    999.94  ...           2.13     145.5
# 2009-01-01 17:00:00  01.01.2009 17:00:00   1000.17  ...           1.63     142.2
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16  ...           1.00     183.7
# 2009-01-01 19:00:00  01.01.2009 19:00:00   1000.22  ...           0.75     176.7
# 2009-01-01 20:00:00  01.01.2009 20:00:00   1000.22  ...           1.13     195.2
# 2009-01-01 21:00:00  01.01.2009 21:00:00   1000.19  ...           0.75     206.3
# 2009-01-01 22:00:00  01.01.2009 22:00:00   1000.00  ...           0.63     175.7
# 2009-01-01 23:00:00  01.01.2009 23:00:00    999.77  ...           1.00     219.3
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59  ...           0.88     155.0
# 2009-01-02 01:00:00  02.01.2009 01:00:00    999.34  ...           1.00     148.1
# 2009-01-02 02:00:00  02.01.2009 02:00:00    998.93  ...           0.88     209.8
#
# [26 rows x 15 columns]

# %%
temp = df['T (degC)']
temp.plot()

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]
def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+5]]
    X.append(row)
    label = df_as_np[i+5]
    y.append(label)
  return np.array(X), np.array(y)

# %%
window_size = 5
X, y = df_to_X_y(temp, window_size)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X
# Out:
# array([[[-8.05],
#         [-8.88],
#         [-8.81],
#         [-9.05],
#         [-9.63]],
#
#        [[-8.88],
#         [-8.81],
#         [-9.05],
#         [-9.63],
#         [-9.67]],
#
#        [[-8.81],
#         [-9.05],
#         [-9.63],
#         [-9.67],
#         [-9.17]],
#
#        ...,
#
#        [[ 2.44],
#         [ 1.29],
#         [-0.42],
#         [-0.98],
#         [-1.4 ]],
#
#        [[ 1.29],
#         [-0.42],
#         [-0.98],
#         [-1.4 ],
#         [-2.75]],
#
#        [[-0.42],
#         [-0.98],
#         [-1.4 ],
#         [-2.75],
#         [-2.89]]])

# %%
y
# Out:
# array([-9.67, -9.17, -8.1 , ..., -2.75, -2.89, -3.93])

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 17,425
# Trainable params: 17,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1867/1875 [============================>.] - ETA: 0s - loss: 38.8128 - root_mean_squared_error: 6.2300
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 17s 8ms/step - loss: 38.6649 - root_mean_squared_error: 6.2181 - val_loss: 1.5243 - val_root_mean_squared_error: 1.2346
# Epoch 2/10
# 1875/1875 [==============================] - ETA: 0s - loss: 2.5865 - root_mean_squared_error: 1.6083
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 13s 7ms/step - loss: 2.5865 - root_mean_squared_error: 1.6083 - val_loss: 0.6721 - val_root_mean_squared_error: 0.8198
# Epoch 3/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 1.0421 - root_mean_squared_error: 1.0208
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 13s 7ms/step - loss: 1.0412 - root_mean_squared_error: 1.0204 - val_loss: 0.5231 - val_root_mean_squared_error: 0.7232
# Epoch 4/10
# 1868/1875 [============================>.] - ETA: 0s - loss: 0.7650 - root_mean_squared_error: 0.8747
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.7645 - root_mean_squared_error: 0.8743 - val_loss: 0.5064 - val_root_mean_squared_error: 0.7116
# Epoch 5/10
# 1873/1875 [============================>.] - ETA: 0s - loss: 0.7021 - root_mean_squared_error: 0.8379
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.7018 - root_mean_squared_error: 0.8377 - val_loss: 0.5016 - val_root_mean_squared_error: 0.7083
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6776 - root_mean_squared_error: 0.8232 - val_loss: 0.5140 - val_root_mean_squared_error: 0.7169
# Epoch 7/10
# 1872/1875 [============================>.] - ETA: 0s - loss: 0.6658 - root_mean_squared_error: 0.8160
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 22s 11ms/step - loss: 0.6665 - root_mean_squared_error: 0.8164 - val_loss: 0.4960 - val_root_mean_squared_error: 0.7043
# Epoch 8/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 0.6588 - root_mean_squared_error: 0.8117
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model1/assets
# INFO:tensorflow:Assets written to: model1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff6c3356e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.6582 - root_mean_squared_error: 0.8113 - val_loss: 0.4921 - val_root_mean_squared_error: 0.7015
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6543 - root_mean_squared_error: 0.8089 - val_loss: 0.4928 - val_root_mean_squared_error: 0.7020
# Epoch 10/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6497 - root_mean_squared_error: 0.8061 - val_loss: 0.4963 - val_root_mean_squared_error: 0.7045

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train_Predictions':train_predictions, 'Actual':y_train})
train_results
# Out:
#        Train_Predictions  Actual
# 0              -9.598334   -9.67
# 1              -9.485751   -9.17
# 2              -8.752005   -8.10
# 3              -7.408553   -7.66
# 4              -7.232960   -7.04
# ...                  ...     ...
# 59995           6.272318    6.07
# 59996           7.235752    9.88
# 59997          12.299301   13.53
# 59998          16.063622   15.43
# 59999          16.304487   15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train_Predictions'][50:100])
plt.plot(train_results['Actual'][50:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
#       Val Predictions  Actuals
# 0           15.410776    14.02
# 1           13.271713    13.67
# 2           13.072651    12.27
# 3           11.518182    11.19
# 4           10.410645    10.85
# ...               ...      ...
# 4995        17.340988    18.27
# 4996        17.446787    17.85
# 4997        17.178505    16.65
# 4998        15.866658    15.85
# 4999        15.098842    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][50:100])
plt.plot(val_results['Actuals'][50:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
#       Test Predictions  Actuals
# 0            14.400454    13.99
# 1            13.251595    13.46
# 2            12.857454    12.93
# 3            12.461508    12.43
# 4            12.027252    12.17
# ...                ...      ...
# 5081         -1.108436    -0.98
# 5082         -1.413458    -1.40
# 5083         -1.611607    -2.75
# 5084         -3.424873    -2.89
# 5085         -3.135078    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][50:100])
plt.plot(test_results['Actuals'][50:100])
